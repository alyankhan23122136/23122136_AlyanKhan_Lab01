# %% [markdown]
# <a href="https://colab.research.google.com/github/alyankhan23122136/23122136_AlyanKhan_Lab01/blob/main/Alyan_Lab04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Federal Urdu University - CS Department Agent
BSCS 6th Semester - Section A

Paste this entire cell into Google Colab.
Contains:
  1. A "library" (Python dict) holding department/timetable data
  2. A role-based Gemini agent that answers questions using that data
"""

# !pip install -U google-genai

from google import genai

client = genai.Client(api_key="Gemini_API_Key")   # <-- put your Gemini API key here

MODEL = "models/gemini-3.6-flash"   # use an available model name from your Gemini account


# =========================================================
# 1. DATA LIBRARY — Federal Urdu University, BSCS 6th Sem, Section A
# =========================================================

university_data = {
    "university": "Federal Urdu University",
    "program": "BSCS",
    "semester": "6th",
}
