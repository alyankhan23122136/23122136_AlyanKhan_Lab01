# %% [markdown]
# <a href="https://colab.research.google.com/github/alyankhan23122136/23122136_AlyanKhan_Lab01/blob/main/Alyan_Lab02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google import genai

# Initialize Client
client = genai.Client(api_key="API_KEY")

print("Gemini Chatbot (type 'exit' to quit)\n")
while True:
    user_input = input("You: ")

    # Exit condition
    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye 👋")
        break

    # Send input using the latest model
    response = client.models.generate_content(
        model="gemini-3.6-flash",
        contents=user_input,
    )

    # Print response
    print("Chatbot:", response.text)
# Out:
# Gemini Chatbot (type 'exit' to quit)
#
# Chatbot: No, I am not human. I am a large language model, trained by Google. How can I help you today?
# Chatbot: I don't know who you are personally! As an AI, I don't have access to your personal information, identity, or past conversations, which helps protect your privacy. Every chat with me starts fresh.
#
# If you'd like to introduce yourself or let me know how I can help you today, feel free to share!
# Chatbot: Goodbye! Have a great day, and feel free to reach out if you need anything else in the future. Take care!
